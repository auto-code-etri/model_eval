# %% [markdown]
# leetcode 각 문제의 아카이브 날짜 확인

# %%
import requests
import pandas as pd

def get_first_archive_timestamp(url):
    cdx_url = "http://web.archive.org/cdx/search/cdx"
    params = {
        "url": url,
        "fl": "timestamp",
        "limit": 1,
        "output": "json"
    }

    response = requests.get(cdx_url, params=params)

    data = response.json()
    if len(data) > 1:
        # 시간 부분 제거하기
        return data[1][0][:8]
    else:
        return None

# CSV 파일 읽기
df = pd.read_csv('leetcode_dataset.csv')

# 'title' 컬럼의 처음 100줄을 불러오기, 소문자로 바꾸고 띄어쓰기를 '-'로 바꾸기
title_list = df['title'].iloc[:100].str.lower().str.replace(' ', '-').tolist()

# 각 제목에 대한 URL의 첫 아카이브 날짜를 저장할 딕셔너리
first_archive_dates = {}

# 각 제목에 대해
for title in title_list:
    # URL 만들기
    url = f"https://leetcode.com/problems/{title}/"
    
    # 첫 아카이브 날짜 얻기
    first_archive_date = get_first_archive_timestamp(url)

    # 딕셔너리에 저장
    first_archive_dates[title] = first_archive_date

# 딕셔너리 출력해서 확인
for title, date in first_archive_dates.items():
    print(f"{title}: {date}")
# Out:
# two-sum: 20150322
# add-two-numbers: 20150322
# longest-substring-without-repeating-characters: 20150322
# median-of-two-sorted-arrays: 20150322
# longest-palindromic-substring: 20150322
# zigzag-conversion: 20150322
# reverse-integer: 20150313
# string-to-integer-(atoi): None
# palindrome-number: 20150315
# regular-expression-matching: 20150322
# container-with-most-water: 20150322
# integer-to-roman: 20150321
# roman-to-integer: 20150321
# longest-common-prefix: 20150322
# 3sum: 20150322
# 3sum-closest: 20150322
# letter-combinations-of-a-phone-number: 20150311
# 4sum: 20150322
# remove-nth-node-from-end-of-list: 20150322
# valid-parentheses: 20150322
# merge-two-sorted-lists: 20150322
# generate-parentheses: 20150322
# merge-k-sorted-lists: 20150310
# swap-nodes-in-pairs: 20150322
# reverse-nodes-in-k-group: 20150322
# remove-duplicates-from-sorted-array: 20150321
# remove-element: 20150322
# implement-strstr(): None
# divide-two-integers: 20150322
# substring-with-concatenation-of-all-words: 20150322
# next-permutation: 20150322
# longest-valid-parentheses: 20150322
# search-in-rotated-sorted-array: 20150320
# find-first-and-last-position-of-element-in-sorted-array: 20190504
# search-insert-position: 20150319
# valid-sudoku: 20150322
# sudoku-solver: 20150322
# count-and-say: 20150322
# combination-sum: 20150322
# combination-sum-ii: 20150322
# first-missing-positive: 20150322
# trapping-rain-water: 20150322
# multiply-strings: 20150322
# wildcard-matching: 20150322
# jump-game-ii: 20150322
# permutations: 20150322
# permutations-ii: 20150322
# rotate-image: 20150322
# group-anagrams: 20170922
# pow(x,-n): None
# n-queens: 20150322
# n-queens-ii: 20150320
# maximum-subarray: 20150322
# spiral-matrix: 20150322
# jump-game: 20150322
# merge-intervals: 20150322
# insert-interval: 20150322
# length-of-last-word: 20150322
# spiral-matrix-ii: 20150322
# permutation-sequence: 20150322
# rotate-list: 20150322
# unique-paths: 20150322
# unique-paths-ii: 20150322
# minimum-path-sum: 20150322
# valid-number: 20150322
# plus-one: 20150322
# add-binary: 20150322
# text-justification: 20150322
# sqrt(x): None
# climbing-stairs: 20150322
# simplify-path: 20150322
# edit-distance: 20150322
# set-matrix-zeroes: 20150322
# search-a-2d-matrix: 20150322
# sort-colors: 20150318
# minimum-window-substring: 20150312
# combinations: 20150316
# subsets: 20150322
# word-search: 20150310
# remove-duplicates-from-sorted-array-ii: 20150322
# search-in-rotated-sorted-array-ii: 20150321
# remove-duplicates-from-sorted-list-ii: 20150322
# remove-duplicates-from-sorted-list: 20150322
# largest-rectangle-in-histogram: 20150322
# maximal-rectangle: 20150322
# partition-list: 20150322
# scramble-string: 20150322
# merge-sorted-array: 20150322
# gray-code: 20150320
# subsets-ii: 20150322
# decode-ways: 20150322
# reverse-linked-list-ii: 20150322
# restore-ip-addresses: 20150322
# binary-tree-inorder-traversal: 20150321
# unique-binary-search-trees-ii: 20150322
# unique-binary-search-trees: 20150322
# interleaving-string: 20150322
# validate-binary-search-tree: 20150310
# recover-binary-search-tree: 20150310
# same-tree: 20150322

# %% [markdown]
# chat GPT 통신 결과에 아카이브 날짜 추가

# %%
import requests
import pandas as pd
import json

def get_first_archive_timestamp(url):
    cdx_url = "http://web.archive.org/cdx/search/cdx"
    params = {
        "url": url,
        "fl": "timestamp",
        "limit": 1,
        "output": "json"
    }

    response = requests.get(cdx_url, params=params)

    data = response.json()
    if len(data) > 1:
        # 시간 부분 제거하기
        return data[1][0][:8]
    else:
        return None

# CSV 파일 읽기
df = pd.read_csv('leetcode_dataset.csv')

# 'title' 컬럼의 처음 100줄을 불러오기, 소문자로 바꾸고 띄어쓰기를 '-'로 바꾸기
title_list = df['title'].iloc[:100].str.lower().str.replace(' ', '-').tolist()

# 각 제목에 대한 URL의 첫 아카이브 날짜를 저장할 딕셔너리
first_archive_dates = {}

# 각 제목에 대해
for title in title_list:
    # URL 만들기
    url = f"https://leetcode.com/problems/{title}/"
    
    # 첫 아카이브 날짜 얻기
    first_archive_date = get_first_archive_timestamp(url)

    # 딕셔너리에 저장
    first_archive_dates[title] = first_archive_date

# JSON 파일 읽기
with open('python-results.json', 'r') as f:
    json_data = json.load(f)

# 날짜 정보 추가
for problem in json_data:
    if problem['title'].lower().replace(' ', '-') in first_archive_dates:
        problem['archive_date'] = first_archive_dates[problem['title'].lower().replace(' ', '-')]

# JSON 파일에 다시 쓰기
with open('python-results.json', 'w') as f:
    json.dump(json_data, f, indent=4)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[2], line 45
#      43 # JSON 파일 읽기
#      44 with open('python-results.json', 'r') as f:
# ---> 45     json_data = json.load(f)
#      47 # 날짜 정보 추가
#      48 for problem in json_data:
#
# File c:\Users\admin\anaconda3\envs\test\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File c:\Users\admin\anaconda3\envs\test\Lib\json\__init__.py:335, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     333 if isinstance(s, str):
#     334     if s.startswith('\ufeff'):
# --> 335         raise JSONDecodeError("Unexpected UTF-8 BOM (decode using utf-8-sig)",
#     336                               s, 0)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
#
# JSONDecodeError: Unexpected UTF-8 BOM (decode using utf-8-sig): line 1 column 1 (char 0)

# %% [markdown]
# leetcode submit 결과에 아카이브 날짜 추가

# %%
import requests
import pandas as pd
import json

def get_first_archive_timestamp(url):
    cdx_url = "http://web.archive.org/cdx/search/cdx"
    params = {
        "url": url,
        "fl": "timestamp",
        "limit": 1,
        "output": "json"
    }

    response = requests.get(cdx_url, params=params)

    data = response.json()
    if len(data) > 1:
        # 시간 부분 제거하기
        return data[1][0][:8]
    else:
        return None

# CSV 파일 읽기
df = pd.read_csv('leetcode_dataset.csv')

# 'title' 컬럼의 처음 100줄을 불러오기, 소문자로 바꾸고 띄어쓰기를 '-'로 바꾸기
title_list = df['title'].iloc[:100].str.lower().str.replace(' ', '-').tolist()

# 각 제목에 대한 URL의 첫 아카이브 날짜를 저장할 딕셔너리
first_archive_dates = {}

# 각 제목에 대해
for title in title_list:
    # URL 만들기
    url = f"https://leetcode.com/problems/{title}/"
    
    # 첫 아카이브 날짜 얻기
    first_archive_date = get_first_archive_timestamp(url)

    # 딕셔너리에 저장
    first_archive_dates[title] = first_archive_date

# JSON 파일 읽기
with open('submit_result.json', 'r') as f:
    json_data = json.load(f)

# 날짜 정보 추가
for problem in json_data:
    if problem['title'].lower().replace(' ', '-') in first_archive_dates:
        problem['archive_date'] = first_archive_dates[problem['title'].lower().replace(' ', '-')]

# JSON 파일에 다시 쓰기
with open('compile_result.json', 'w') as f:
    json.dump(json_data, f, indent=4)
